# %%
import pandas as pd
import numpy as np
from IPython.display import display


file_name = 'Camp_Market_cleaned_omar.csv'
df = pd.read_csv(file_name, delimiter=';')

# %% [markdown]
# # Définition des Bornes de Quantiles (Âge et Revenu)

# %%
age_qcut_series, age_bins = pd.qcut(df['Age'], q=4, retbins=True)

print("\n Bornes pour Age Groupe (Quartiles d'Age) ")

print(f"  Q1_Age (les 25% plus jeunes): de {age_bins[0]} à {age_bins[1]} ans")
print(f"  Q2_Age (25% suivants):      de {age_bins[1]} à {age_bins[2]} ans")
print(f"  Q3_Age (25% suivants):      de {age_bins[2]} à {age_bins[3]} ans")
print(f"  Q4_Age (les 25% plus âgés):   de {age_bins[3]} à {age_bins[4]} ans")


# --- 3. Calcul et affichage des bornes pour 'Income_Group' ---
# retbins=True renvoie les bornes (bins)
income_qcut_series, income_bins = pd.qcut(df['Income'], q=4, retbins=True)

print("\n Bornes pour Income Groupe (Quartiles de Revenu) ")

# .2f formate le nombre avec 2 décimales pour l'affichage
print(f"  Q1_Income (les 25% revenus les plus bas): de {income_bins[0]:.2f} à {income_bins[1]:.2f}")
print(f"  Q2_Income (25% suivants):               de {income_bins[1]:.2f} à {income_bins[2]:.2f}")
print(f"  Q3_Income (25% suivants):               de {income_bins[2]:.2f} à {income_bins[3]:.2f}")
print(f"  Q4_Income (les 25% revenus les plus hauts): de {income_bins[3]:.2f} à {income_bins[4]:.2f}")
# Out:
#  Bornes pour Age Groupe (Quartiles d'Age)
#   Q1_Age (les 25% plus jeunes): de 29.0 à 48.0 ans
#   Q2_Age (25% suivants):      de 48.0 à 55.0 ans
#   Q3_Age (25% suivants):      de 55.0 à 66.0 ans
#   Q4_Age (les 25% plus âgés):   de 66.0 à 85.0 ans
#
#  Bornes pour Income Groupe (Quartiles de Revenu)
#   Q1_Income (les 25% revenus les plus bas): de 1730.00 à 35523.00
#   Q2_Income (25% suivants):               de 35523.00 à 51381.50
#   Q3_Income (25% suivants):               de 51381.50 à 68281.00
#   Q4_Income (les 25% revenus les plus hauts): de 68281.00 à 666666.00

# %% [markdown]
# # Analyse de la Campagne "Response = 1"

# %%
# Définition des variables de DÉPENSES
mnt_columns = [
    'MntWines', 
    'MntFruits', 
    'MntMeatProducts', 
    'MntFishProducts', 
    'MntSweetProducts', 
    'MntGoldProds'
]

# Définition des variables de FRÉQUENCE (SANS TotalPurchases)
num_columns = [
    'NumDealsPurchases',
    'NumWebPurchases',
    'NumCatalogPurchases',
    'NumStorePurchases',
    'NumWebVisitsMonth'
    # TotalPurchases a été retiré
]

# Définition de la palette de couleurs
cmap_colors = 'Greens'

# --- 3. Discrétisation des variables continues (Âge et Revenu) ---
try:
    # Stratégie de discrétisation par quantiles (effectifs égaux)
    df['Age_Group'] = pd.qcut(df['Age'], q=4, labels=['Q1_Age', 'Q2_Age', 'Q3_Age', 'Q4_Age'])
    df['Income_Group'] = pd.qcut(df['Income'], q=4, labels=['Q1_Income', 'Q2_Income', 'Q3_Income', 'Q4_Income'])

except ValueError as e:
    # Fallback : stratégie par intervalles égaux
    print(f"Erreur de discrétisation (qcut) : {e}. Passage en 'cut'.")
    df['Age_Group'] = pd.cut(df['Age'], bins=4, labels=['Bin1_Age', 'Bin2_Age', 'Bin3_Age', 'Bin4_Age'])
    df['Income_Group'] = pd.cut(df['Income'], bins=4, labels=['Bin1_Income', 'Bin2_Income', 'Bin3_Income', 'Bin4_Income'])


# --- 4. Définition des groupes croisés --- MODIFICATION ---
# On filtre le DataFrame pour ne garder que ceux qui ont accepté
df_acceptants = df[df['Response'] == 1].copy()

# On met à jour les clés (Response est inutile, c'est toujours 1)
grouping_keys = ['Age_Group', 'Income_Group']


print("\n--- Analyse Croisée (Acceptants Uniquement) : DÉPENSES (Mnt) ---")

# --- 5. Heatmap : Dépenses (Mnt) par [Age_Group, Income_Group] --- MODIFICATION ---
mnt_analysis_crossed = df_acceptants.groupby(grouping_keys, observed=True)[mnt_columns].sum()
display(mnt_analysis_crossed.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées (Mnt) par Âge et Revenu (Acceptants Uniquement)"))


print("\n--- Analyse Croisée (Acceptants Uniquement) : FRÉQUENCES (Num) ---")

# --- 6. Heatmap : Fréquences (Num) par [Age_Group, Income_Group] --- MODIFICATION ---
num_analysis_crossed = df_acceptants.groupby(grouping_keys, observed=True)[num_columns].sum()
display(num_analysis_crossed.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées (Num) par Âge et Revenu (Acceptants Uniquement)"))
# Out:
# --- Analyse Croisée (Acceptants Uniquement) : DÉPENSES (Mnt) ---
# <style type="text/css">
# #T_a85fc_row0_col0, #T_a85fc_row0_col3, #T_a85fc_row0_col4, #T_a85fc_row1_col1, #T_a85fc_row1_col3, #T_a85fc_row1_col4, #T_a85fc_row2_col1, #T_a85fc_row2_col3, #T_a85fc_row4_col1, #T_a85fc_row4_col3, #T_a85fc_row4_col4, #T_a85fc_row5_col1, #T_a85fc_row5_col3, #T_a85fc_row5_col4, #T_a85fc_row6_col1, #T_a85fc_row6_col3, #T_a85fc_row6_col4, #T_a85fc_row8_col0, #T_a85fc_row8_col2, #T_a85fc_row8_col3, #T_a85fc_row8_col5, #T_a85fc_row9_col1, #T_a85fc_row9_col3, #T_a85fc_row9_col4, #T_a85fc_row10_col3, #T_a85fc_row10_col4, #T_a85fc_row13_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_a85fc_row0_col1, #T_a85fc_row2_col4, #T_a85fc_row8_col1, #T_a85fc_row8_col4, #T_a85fc_row12_col0, #T_a85fc_row12_col1, #T_a85fc_row12_col2, #T_a85fc_row12_col3, #T_a85fc_row12_col4, #T_a85fc_row12_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a85fc_row0_col2, #T_a85fc_row2_col5, #T_a85fc_row4_col2, #T_a85fc_row4_col5, #T_a85fc_row6_col5, #T_a85fc_row10_col1, #T_a85fc_row13_col4, #T_a85fc_row14_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_a85fc_row0_col5, #T_a85fc_row4_col0, #T_a85fc_row13_col3, #T_a85fc_row13_col5, #T_a85fc_row14_col1, #T_a85fc_row14_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_a85fc_row1_col0, #T_a85fc_row6_col2, #T_a85fc_row10_col5, #T_a85fc_row11_col1, #T_a85fc_row11_col4, #T_a85fc_row11_col5, #T_a85fc_row14_col5, #T_a85fc_row15_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_a85fc_row1_col2 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_a85fc_row1_col5, #T_a85fc_row5_col5, #T_a85fc_row9_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_a85fc_row2_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_a85fc_row2_col2 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_a85fc_row3_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a85fc_row3_col1, #T_a85fc_row5_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_a85fc_row3_col2 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_a85fc_row3_col3 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_a85fc_row3_col4, #T_a85fc_row7_col3, #T_a85fc_row15_col5 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_a85fc_row3_col5 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_a85fc_row5_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_a85fc_row6_col0 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_a85fc_row7_col0 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_a85fc_row7_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_a85fc_row7_col2 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_a85fc_row7_col4, #T_a85fc_row7_col5 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_a85fc_row9_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_a85fc_row9_col2 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_a85fc_row10_col0 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_a85fc_row10_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_a85fc_row11_col0 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_a85fc_row11_col2 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_a85fc_row11_col3, #T_a85fc_row15_col4 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_a85fc_row13_col0 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_a85fc_row13_col2 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_a85fc_row14_col0 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_a85fc_row14_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_a85fc_row15_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_a85fc_row15_col2 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_a85fc_row15_col3 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# </style>
# <table id="T_a85fc">
#   <caption>Dépenses cumulées (Mnt) par Âge et Revenu (Acceptants Uniquement)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a85fc_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_a85fc_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_a85fc_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_a85fc_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_a85fc_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_a85fc_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_Group</th>
#       <th class="index_name level1" >Income_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a85fc_level0_row0" class="row_heading level0 row0" rowspan="4">Q1_Age</th>
#       <th id="T_a85fc_level1_row0" class="row_heading level1 row0" >Q1_Income</th>
#       <td id="T_a85fc_row0_col0" class="data row0 col0" >404</td>
#       <td id="T_a85fc_row0_col1" class="data row0 col1" >148</td>
#       <td id="T_a85fc_row0_col2" class="data row0 col2" >565</td>
#       <td id="T_a85fc_row0_col3" class="data row0 col3" >159</td>
#       <td id="T_a85fc_row0_col4" class="data row0 col4" >179</td>
#       <td id="T_a85fc_row0_col5" class="data row0 col5" >802</td>
#     </tr>
#     <tr>
#       <th id="T_a85fc_level1_row1" class="row_heading level1 row1" >Q2_Income</th>
#       <td id="T_a85fc_row1_col0" class="data row1 col0" >1816</td>
#       <td id="T_a85fc_row1_col1" class="data row1 col1" >290</td>
#       <td id="T_a85fc_row1_col2" class="data row1 col2" >1498</td>
#       <td id="T_a85fc_row1_col3" class="data row1 col3" >343</td>
#       <td id="T_a85fc_row1_col4" class="data row1 col4" >253</td>
#       <td id="T_a85fc_row1_col5" class="data row1 col5" >721</td>
#     </tr>
#     <tr>
#       <th id="T_a85fc_level1_row2" class="row_heading level1 row2" >Q3_Income</th>
#       <td id="T_a85fc_row2_col0" class="data row2 col0" >5595</td>
#       <td id="T_a85fc_row2_col1" class="data row2 col1" >437</td>
#       <td id="T_a85fc_row2_col2" class="data row2 col2" >1884</td>
#       <td id="T_a85fc_row2_col3" class="data row2 col3" >304</td>
#       <td id="T_a85fc_row2_col4" class="data row2 col4" >128</td>
#       <td id="T_a85fc_row2_col5" class="data row2 col5" >590</td>
#     </tr>
#     <tr>
#       <th id="T_a85fc_level1_row3" class="row_heading level1 row3" >Q4_Income</th>
#       <td id="T_a85fc_row3_col0" class="data row3 col0" >39300</td>
#       <td id="T_a85fc_row3_col1" class="data row3 col1" >3082</td>
#       <td id="T_a85fc_row3_col2" class="data row3 col2" >28008</td>
#       <td id="T_a85fc_row3_col3" class="data row3 col3" >4238</td>
#       <td id="T_a85fc_row3_col4" class="data row3 col4" >3348</td>
#       <td id="T_a85fc_row3_col5" class="data row3 col5" >4086</td>
#     </tr>
#     <tr>
#       <th id="T_a85fc_level0_row4" class="row_heading level0 row4" rowspan="4">Q2_Age</th>
#       <th id="T_a85fc_level1_row4" class="row_heading level1 row4" >Q1_Income</th>
#       <td id="T_a85fc_row4_col0" class="data row4 col0" >792</td>
#       <td id="T_a85fc_row4_col1" class="data row4 col1" >194</td>
#       <td id="T_a85fc_row4_col2" class="data row4 col2" >505</td>
#       <td id="T_a85fc_row4_col3" class="data row4 col3" >229</td>
#       <td id="T_a85fc_row4_col4" class="data row4 col4" >165</td>
#       <td id="T_a85fc_row4_col5" class="data row4 col5" >534</td>
#     </tr>
#     <tr>
#       <th id="T_a85fc_level1_row5" class="row_heading level1 row5" >Q2_Income</th>
#       <td id="T_a85fc_row5_col0" class="data row5 col0" >3168</td>
#       <td id="T_a85fc_row5_col1" class="data row5 col1" >193</td>
#       <td id="T_a85fc_row5_col2" class="data row5 col2" >1242</td>
#       <td id="T_a85fc_row5_col3" class="data row5 col3" >311</td>
#       <td id="T_a85fc_row5_col4" class="data row5 col4" >261</td>
#       <td id="T_a
# --- Analyse Croisée (Acceptants Uniquement) : FRÉQUENCES (Num) ---
# <style type="text/css">
# #T_34387_row0_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_34387_row0_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_34387_row0_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_34387_row0_col3, #T_34387_row2_col3, #T_34387_row4_col1, #T_34387_row4_col3, #T_34387_row9_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_34387_row0_col4 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_34387_row1_col0, #T_34387_row3_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_34387_row1_col1, #T_34387_row9_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_34387_row1_col2, #T_34387_row2_col0 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_34387_row1_col3 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_34387_row1_col4, #T_34387_row11_col4 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_34387_row2_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_34387_row2_col2, #T_34387_row6_col2, #T_34387_row15_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_34387_row2_col4, #T_34387_row11_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_34387_row3_col1 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_34387_row3_col2 {
#   background-color: #18823d;
#   color: #f1f1f1;
# }
# #T_34387_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_34387_row3_col4 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_34387_row4_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_34387_row4_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_34387_row4_col4, #T_34387_row11_col2 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_34387_row5_col0, #T_34387_row6_col3, #T_34387_row10_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_34387_row5_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_34387_row5_col2, #T_34387_row8_col1, #T_34387_row9_col2 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_34387_row5_col3 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_34387_row5_col4 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_34387_row6_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_34387_row6_col1 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_34387_row6_col4 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_34387_row7_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_34387_row7_col1 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_34387_row7_col2, #T_34387_row15_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_34387_row7_col3 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_34387_row7_col4 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_34387_row8_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_34387_row8_col2, #T_34387_row12_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_34387_row8_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_34387_row8_col4 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_34387_row9_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_34387_row9_col4, #T_34387_row14_col0 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_34387_row10_col0 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_34387_row10_col1 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_34387_row10_col3 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_34387_row10_col4 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_34387_row11_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_34387_row11_col3 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_34387_row12_col0, #T_34387_row12_col1, #T_34387_row12_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_34387_row12_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_34387_row13_col0 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_34387_row13_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_34387_row13_col2 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_34387_row13_col3, #T_34387_row15_col4 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_34387_row13_col4 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_34387_row14_col1 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_34387_row14_col2 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_34387_row14_col3 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_34387_row14_col4 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_34387_row15_col2 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_34387_row15_col3 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_34387">
#   <caption>Fréquences cumulées (Num) par Âge et Revenu (Acceptants Uniquement)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34387_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_34387_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_34387_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_34387_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_34387_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_Group</th>
#       <th class="index_name level1" >Income_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34387_level0_row0" class="row_heading level0 row0" rowspan="4">Q1_Age</th>
#       <th id="T_34387_level1_row0" class="row_heading level1 row0" >Q1_Income</th>
#       <td id="T_34387_row0_col0" class="data row0 col0" >55</td>
#       <td id="T_34387_row0_col1" class="data row0 col1" >53</td>
#       <td id="T_34387_row0_col2" class="data row0 col2" >23</td>
#       <td id="T_34387_row0_col3" class="data row0 col3" >60</td>
#       <td id="T_34387_row0_col4" class="data row0 col4" >186</td>
#     </tr>
#     <tr>
#       <th id="T_34387_level1_row1" class="row_heading level1 row1" >Q2_Income</th>
#       <td id="T_34387_row1_col0" class="data row1 col0" >47</td>
#       <td id="T_34387_row1_col1" class="data row1 col1" >72</td>
#       <td id="T_34387_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_34387_row1_col3" class="data row1 col3" >75</td>
#       <td id="T_34387_row1_col4" class="data row1 col4" >124</td>
#     </tr>
#     <tr>
#       <th id="T_34387_level1_row2" class="row_heading level1 row2" >Q3_Income</th>
#       <td id="T_34387_row2_col0" class="data row2 col0" >24</td>
#       <td id="T_34387_row2_col1" class="data row2 col1" >50</td>
#       <td id="T_34387_row2_col2" class="data row2 col2" >35</td>
#       <td id="T_34387_row2_col3" class="data row2 col3" >60</td>
#       <td id="T_34387_row2_col4" class="data row2 col4" >44</td>
#     </tr>
#     <tr>
#       <th id="T_34387_level1_row3" class="row_heading level1 row3" >Q4_Income</th>
#       <td id="T_34387_row3_col0" class="data row3 col0" >47</td>
#       <td id="T_34387_row3_col1" class="data row3 col1" >274</td>
#       <td id="T_34387_row3_col2" class="data row3 col2" >321</td>
#       <td id="T_34387_row3_col3" class="data row3 col3" >407</td>
#       <td id="T_34387_row3_col4" class="data row3 col4" >136</td>
#     </tr>
#     <tr>
#       <th id="T_34387_level0_row4" class="row_heading level0 row4" rowspan="4">Q2_Age</th>
#       <th id="T_34387_level1_row4" class="row_heading level1 row4" >Q1_Income</th>
#       <td id="T_34387_row4_col0" class="data row4 col0" >56</td>
#       <td id="T_34387_row4_col1" class="data row4 col1" >60</td>
#       <td id="T_34387_row4_col2" class="data row4 col2" >19</td>
#       <td id="T_34387_row4_col3" class="data row4 col3" >60</td>
#       <td id="T_34387_row4_col4" class="data row4 col4" >184</td>
#     </tr>
#     <tr>
#       <th id="T_34387_level1_row5" class="row_heading level1 row5" >Q2_I

# %% [markdown]
# # Analyse de la Fréquence d'Achat par Segment

# %%
# --- 2. Pré-traitement et configuration de l'analyse ---

# === MODIFICATION ICI ===
# Définition des variables quantitatives (Nombre d'achats/visites)
columns_to_analyze = [
    'NumDealsPurchases',
    'NumWebPurchases',
    'NumCatalogPurchases',
    'NumStorePurchases',
    'NumWebVisitsMonth',
    
]

# Définition de la palette de couleurs (séquentielle 'Greens')
cmap_colors = 'Greens'

# --- 3. Discrétisation des variables continues (Âge et Revenu) ---
# (Cette partie reste identique)
try:
    # Stratégie de discrétisation par quantiles (effectifs égaux)
    df['Age_Group'] = pd.qcut(df['Age'], q=4, labels=['Q1_Age', 'Q2_Age', 'Q3_Age', 'Q4_Age'])
    df['Income_Group'] = pd.qcut(df['Income'], q=4, labels=['Q1_Income', 'Q2_Income', 'Q3_Income', 'Q4_Income'])
  
except ValueError as e:
    # Fallback : stratégie par intervalles égaux
    print(f"Erreur de discrétisation (qcut) : {e}. Passage en 'cut'.")
    df['Age_Group'] = pd.cut(df['Age'], bins=4, labels=['Bin1_Age', 'Bin2_Age', 'Bin3_Age', 'Bin4_Age'])
    df['Income_Group'] = pd.cut(df['Income'], bins=4, labels=['Bin1_Income', 'Bin2_Income', 'Bin3_Income', 'Bin4_Income'])


# --- 4. Analyse : Somme des Fréquences par Niveau d'études ---
education_analysis = df.groupby('Education')[columns_to_analyze].sum()
display(education_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par niveau d'études"))

# --- 5. Analyse : Somme des Fréquences par Statut marital ---
marital_analysis = df.groupby('Marital_Status')[columns_to_analyze].sum()
display(marital_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par statut marital"))

# --- 6. Analyse : Somme des Fréquences par Nombre total d'enfants ---
total_kids_analysis = df.groupby('TotalKids')[columns_to_analyze].sum()
display(total_kids_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par nombre total d'enfants"))

# --- 7. Analyse : Somme des Fréquences par Enfants (0-12 ans) ---
kidhome_analysis = df.groupby('Kidhome')[columns_to_analyze].sum()
display(kidhome_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par nombre de jeunes enfants"))

# --- 8. Analyse : Somme des Fréquences par Adolescents ---
teenhome_analysis = df.groupby('Teenhome')[columns_to_analyze].sum()
display(teenhome_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par nombre d'adolescents"))

# --- 9. Analyse : Somme des Fréquences par Groupe d'âge (quartiles) ---
age_group_analysis = df.groupby('Age_Group', observed=True)[columns_to_analyze].sum()
display(age_group_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par groupe d'âge"))

# --- 10. Analyse : Somme des Fréquences par Total de campagnes marketing acceptées ---
acceptedcmp_analysis = df.groupby('AcceptedCmp_total')[columns_to_analyze].sum()
display(acceptedcmp_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par total de campagnes acceptées"))

# --- 11. Analyse : Somme des Fréquences par Groupe de revenu (quartiles) ---
income_group_analysis = df.groupby('Income_Group', observed=True)[columns_to_analyze].sum()
display(income_group_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Fréquences cumulées par groupe de revenu"))
# Out:
# <style type="text/css">
# #T_f4d86_row0_col0 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_f4d86_row0_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_f4d86_row0_col2 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_f4d86_row0_col3 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_f4d86_row0_col4 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_f4d86_row1_col0, #T_f4d86_row1_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_f4d86_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_f4d86_row1_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_f4d86_row1_col4 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_f4d86_row2_col0 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_f4d86_row2_col1 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_f4d86_row2_col2 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_f4d86_row2_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f4d86_row2_col4 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_f4d86_row3_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_f4d86_row3_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_f4d86_row3_col2 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_f4d86_row3_col3 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_f4d86_row3_col4 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_f4d86_row4_col0 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_f4d86_row4_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_f4d86_row4_col2 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_f4d86_row4_col3 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_f4d86_row4_col4 {
#   background-color: #9ed798;
#   color: #000000;
# }
# </style>
# <table id="T_f4d86">
#   <caption>Fréquences cumulées par niveau d'études</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4d86_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_f4d86_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_f4d86_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_f4d86_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_f4d86_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4d86_level0_row0" class="row_heading level0 row0" >2n Cycle</th>
#       <td id="T_f4d86_row0_col0" class="data row0 col0" >454</td>
#       <td id="T_f4d86_row0_col1" class="data row0 col1" >754</td>
#       <td id="T_f4d86_row0_col2" class="data row0 col2" >470</td>
#       <td id="T_f4d86_row0_col3" class="data row0 col3" >1114</td>
#       <td id="T_f4d86_row0_col4" class="data row0 col4" >1098</td>
#     </tr>
#     <tr>
#       <th id="T_f4d86_level0_row1" class="row_heading level0 row1" >Basic</th>
#       <td id="T_f4d86_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_f4d86_row1_col1" class="data row1 col1" >102</td>
#       <td id="T_f4d86_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_f4d86_row1_col3" class="data row1 col3" >154</td>
#       <td id="T_f4d86_row1_col4" class="data row1 col4" >371</td>
#     </tr>
#     <tr>
#       <th id="T_f4d86_level0_row2" class="row_heading level0 row2" >Graduation</th>
#       <td id="T_f4d86_row2_col0" class="data row2 col0" >2603</td>
#       <td id="T_f4d86_row2_col1" class="data row2 col1" >4649</td>
#       <td id="T_f4d86_row2_col2" class="data row2 col2" >3072</td>
#       <td id="T_f4d86_row2_col3" class="data row2 col3" >6570</td>
#       <td id="T_f4d86_row2_col4" class="data row2 col4" >5959</td>
#     </tr>
#     <tr>
#       <th id="T_f4d86_level0_row3" class="row_heading level0 row3" >Master</th>
#       <td id="T_f4d86_row3_col0" class="data row3 col0" >898</td>
#       <td id="T_f4d86_row3_col1" class="data row3 col1" >1492</td>
#       <td id="T_f4d86_row3_col2" class="data row3 col2" >951</td>
#       <td id="T_f4d86_row3_col3" class="data row3 col3" >2182</td>
#       <td id="T_f4d86_row3_col4" class="data row3 col4" >1916</td>
#     </tr>
#     <tr>
#       <th id="T_f4d86_level0_row4" class="row_heading level0 row4" >PhD</th>
#       <td id="T_f4d86_row4_col0" class="data row4 col0" >1153</td>
#       <td id="T_f4d86_row4_col1" class="data row4 col1" >2146</td>
#       <td id="T_f4d86_row4_col2" class="data row4 col2" >1437</td>
#       <td id="T_f4d86_row4_col3" class="data row4 col3" >2942</td>
#       <td id="T_f4d86_row4_col4" class="data row4 col4" >2555</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1d050_row0_col0, #T_1d050_row0_col1, #T_1d050_row0_col2, #T_1d050_row0_col3, #T_1d050_row0_col4, #T_1d050_row1_col0, #T_1d050_row1_col1, #T_1d050_row1_col2, #T_1d050_row1_col3, #T_1d050_row1_col4, #T_1d050_row7_col0, #T_1d050_row7_col1, #T_1d050_row7_col2, #T_1d050_row7_col3, #T_1d050_row7_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_1d050_row2_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_1d050_row2_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_1d050_row2_col2 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_1d050_row2_col3, #T_1d050_row5_col0 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_1d050_row2_col4 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_1d050_row3_col0 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_1d050_row3_col1 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_1d050_row3_col2 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_1d050_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_1d050_row3_col4 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_1d050_row4_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_1d050_row4_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_1d050_row4_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_1d050_row4_col3 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_1d050_row4_col4 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_1d050_row5_col1 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_1d050_row5_col2 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_1d050_row5_col3 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_1d050_row5_col4 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_1d050_row6_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_1d050_row6_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_1d050_row6_col2 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_1d050_row6_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_1d050_row6_col4 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# </style>
# <table id="T_1d050">
#   <caption>Fréquences cumulées par statut marital</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d050_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_1d050_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_1d050_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_1d050_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_1d050_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Marital_Status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d050_level0_row0" class="row_heading level0 row0" >Absurd</th>
#       <td id="T_1d050_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_1d050_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_1d050_row0_col2" class="data row0 col2" >15</td>
#       <td id="T_1d050_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_1d050_row0_col4" class="data row0 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row1" class="row_heading level0 row1" >Alone</th>
#       <td id="T_1d050_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_1d050_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_1d050_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_1d050_row1_col3" class="data row1 col3" >12</td>
#       <td id="T_1d050_row1_col4" class="data row1 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row2" class="row_heading level0 row2" >Divorced</th>
#       <td id="T_1d050_row2_col0" class="data row2 col0" >564</td>
#       <td id="T_1d050_row2_col1" class="data row2 col1" >998</td>
#       <td id="T_1d050_row2_col2" class="data row2 col2" >619</td>
#       <td id="T_1d050_row2_col3" class="data row2 col3" >1348</td>
#       <td id="T_1d050_row2_col4" class="data row2 col4" >1268</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row3" class="row_heading level0 row3" >Married</th>
#       <td id="T_1d050_row3_col0" class="data row3 col0" >2067</td>
#       <td id="T_1d050_row3_col1" class="data row3 col1" >3532</td>
#       <td id="T_1d050_row3_col2" class="data row3 col2" >2268</td>
#       <td id="T_1d050_row3_col3" class="data row3 col3" >5055</td>
#       <td id="T_1d050_row3_col4" class="data row3 col4" >4635</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row4" class="row_heading level0 row4" >Single</th>
#       <td id="T_1d050_row4_col0" class="data row4 col0" >1022</td>
#       <td id="T_1d050_row4_col1" class="data row4 col1" >1858</td>
#       <td id="T_1d050_row4_col2" class="data row4 col2" >1248</td>
#       <td id="T_1d050_row4_col3" class="data row4 col3" >2705</td>
#       <td id="T_1d050_row4_col4" class="data row4 col4" >2532</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row5" class="row_heading level0 row5" >Together</th>
#       <td id="T_1d050_row5_col0" class="data row5 col0" >1347</td>
#       <td id="T_1d050_row5_col1" class="data row5 col1" >2363</td>
#       <td id="T_1d050_row5_col2" class="data row5 col2" >1546</td>
#       <td id="T_1d050_row5_col3" class="data row5 col3" >3323</td>
#       <td id="T_1d050_row5_col4" class="data row5 col4" >3050</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row6" class="row_heading level0 row6" >Widow</th>
#       <td id="T_1d050_row6_col0" class="data row6 col0" >180</td>
#       <td id="T_1d050_row6_col1" class="data row6 col1" >356</td>
#       <td id="T_1d050_row6_col2" class="data row6 col2" >256</td>
#       <td id="T_1d050_row6_col3" class="data row6 col3" >494</td>
#       <td id="T_1d050_row6_col4" class="data row6 col4" >376</td>
#     </tr>
#     <tr>
#       <th id="T_1d050_level0_row7" class="row_heading level0 row7" >YOLO</th>
#       <td id="T_1d050_row7_col0" class="data row7 col0" >10</td>
#       <td id="T_1d050_row7_col1" class="data row7 col1" >14</td>
#       <td id="T_1d050_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_1d050_row7_col3" class="data row7 col3" >12</td>
#       <td id="T_1d050_row7_col4" class="data row7 col4" >16</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_75289_row0_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_75289_row0_col1, #T_75289_row1_col0 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_75289_row0_col2 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_75289_row0_col3 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_75289_row0_col4 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_75289_row1_col1 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_75289_row1_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_75289_row1_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_75289_row1_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_75289_row2_col0 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_75289_row2_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_75289_row2_col2 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_75289_row2_col3 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_75289_row2_col4 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_75289_row3_col0, #T_75289_row3_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_75289_row3_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_75289_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_75289_row3_col4 {
#   background-color: #f1faee;
#   color: #000000;
# }
# </style>
# <table id="T_75289">
#   <caption>Fréquences cumulées par nombre total d'enfants</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75289_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_75289_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_75289_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_75289_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_75289_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >TotalKids</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75289_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75289_row0_col0" class="data row0 col0" >726</td>
#       <td id="T_75289_row0_col1" class="data row0 col1" >2799</td>
#       <td id="T_75289_row0_col2" class="data row0 col2" >3030</td>
#       <td id="T_75289_row0_col3" class="data row0 col3" >4631</td>
#       <td id="T_75289_row0_col4" class="data row0 col4" >2217</td>
#     </tr>
#     <tr>
#       <th id="T_75289_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75289_row1_col0" class="data row1 col0" >2781</td>
#       <td id="T_75289_row1_col1" class="data row1 col1" >4831</td>
#       <td id="T_75289_row1_col2" class="data row1 col2" >2406</td>
#       <td id="T_75289_row1_col3" class="data row1 col3" >6306</td>
#       <td id="T_75289_row1_col4" class="data row1 col4" >6687</td>
#     </tr>
#     <tr>
#       <th id="T_75289_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75289_row2_col0" class="data row2 col0" >1497</td>
#       <td id="T_75289_row2_col1" class="data row2 col1" >1361</td>
#       <td id="T_75289_row2_col2" class="data row2 col2" >464</td>
#       <td id="T_75289_row2_col3" class="data row2 col3" >1815</td>
#       <td id="T_75289_row2_col4" class="data row2 col4" >2653</td>
#     </tr>
#     <tr>
#       <th id="T_75289_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75289_row3_col0" class="data row3 col0" >201</td>
#       <td id="T_75289_row3_col1" class="data row3 col1" >152</td>
#       <td id="T_75289_row3_col2" class="data row3 col2" >56</td>
#       <td id="T_75289_row3_col3" class="data row3 col3" >210</td>
#       <td id="T_75289_row3_col4" class="data row3 col4" >342</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_290c9_row0_col0 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_290c9_row0_col1 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_290c9_row0_col2 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_290c9_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_290c9_row0_col4 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_290c9_row1_col0 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_290c9_row1_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_290c9_row1_col2 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_290c9_row1_col3 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_290c9_row1_col4 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_290c9_row2_col0, #T_290c9_row2_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_290c9_row2_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_290c9_row2_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_290c9_row2_col4 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_290c9">
#   <caption>Fréquences cumulées par nombre de jeunes enfants</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_290c9_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_290c9_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_290c9_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_290c9_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_290c9_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Kidhome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_290c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_290c9_row0_col0" class="data row0 col0" >2512</td>
#       <td id="T_290c9_row0_col1" class="data row0 col1" >6426</td>
#       <td id="T_290c9_row0_col2" class="data row0 col2" >5112</td>
#       <td id="T_290c9_row0_col3" class="data row0 col3" >9326</td>
#       <td id="T_290c9_row0_col4" class="data row0 col4" >5624</td>
#     </tr>
#     <tr>
#       <th id="T_290c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_290c9_row1_col0" class="data row1 col0" >2557</td>
#       <td id="T_290c9_row1_col1" class="data row1 col1" >2583</td>
#       <td id="T_290c9_row1_col2" class="data row1 col2" >810</td>
#       <td id="T_290c9_row1_col3" class="data row1 col3" >3471</td>
#       <td id="T_290c9_row1_col4" class="data row1 col4" >5955</td>
#     </tr>
#     <tr>
#       <th id="T_290c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_290c9_row2_col0" class="data row2 col0" >136</td>
#       <td id="T_290c9_row2_col1" class="data row2 col1" >134</td>
#       <td id="T_290c9_row2_col2" class="data row2 col2" >34</td>
#       <td id="T_290c9_row2_col3" class="data row2 col3" >165</td>
#       <td id="T_290c9_row2_col4" class="data row2 col4" >320</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dd761_row0_col0 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_dd761_row0_col1 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_dd761_row0_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_dd761_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dd761_row0_col4 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_dd761_row1_col0 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_dd761_row1_col1 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_dd761_row1_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_dd761_row1_col3 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_dd761_row1_col4 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_dd761_row2_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_dd761_row2_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_dd761_row2_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_dd761_row2_col3 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_dd761_row2_col4 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# </style>
# <table id="T_dd761">
#   <caption>Fréquences cumulées par nombre d'adolescents</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd761_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_dd761_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_dd761_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_dd761_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_dd761_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Teenhome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd761_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd761_row0_col0" class="data row0 col0" >1838</td>
#       <td id="T_dd761_row0_col1" class="data row0 col1" >4234</td>
#       <td id="T_dd761_row0_col2" class="data row0 col2" >3457</td>
#       <td id="T_dd761_row0_col3" class="data row0 col3" >6522</td>
#       <td id="T_dd761_row0_col4" class="data row0 col4" >5762</td>
#     </tr>
#     <tr>
#       <th id="T_dd761_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd761_row1_col0" class="data row1 col0" >3185</td>
#       <td id="T_dd761_row1_col1" class="data row1 col1" >4660</td>
#       <td id="T_dd761_row1_col2" class="data row1 col2" >2374</td>
#       <td id="T_dd761_row1_col3" class="data row1 col3" >6115</td>
#       <td id="T_dd761_row1_col4" class="data row1 col4" >5850</td>
#     </tr>
#     <tr>
#       <th id="T_dd761_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd761_row2_col0" class="data row2 col0" >182</td>
#       <td id="T_dd761_row2_col1" class="data row2 col1" >249</td>
#       <td id="T_dd761_row2_col2" class="data row2 col2" >125</td>
#       <td id="T_dd761_row2_col3" class="data row2 col3" >325</td>
#       <td id="T_dd761_row2_col4" class="data row2 col4" >287</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a32b3_row0_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a32b3_row0_col1, #T_a32b3_row1_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_a32b3_row0_col2 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_a32b3_row0_col3 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_a32b3_row0_col4 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_a32b3_row1_col0 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_a32b3_row1_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_a32b3_row1_col3 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_a32b3_row1_col4 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_a32b3_row2_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_a32b3_row2_col1 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_a32b3_row2_col2 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_a32b3_row2_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a32b3_row2_col4 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_a32b3_row3_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_a32b3_row3_col1 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_a32b3_row3_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_a32b3_row3_col3 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_a32b3_row3_col4 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a32b3">
#   <caption>Fréquences cumulées par groupe d'âge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a32b3_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_a32b3_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_a32b3_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_a32b3_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_a32b3_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a32b3_level0_row0" class="row_heading level0 row0" >Q1_Age</th>
#       <td id="T_a32b3_row0_col0" class="data row0 col0" >1189</td>
#       <td id="T_a32b3_row0_col1" class="data row0 col1" >2154</td>
#       <td id="T_a32b3_row0_col2" class="data row0 col2" >1427</td>
#       <td id="T_a32b3_row0_col3" class="data row0 col3" >3212</td>
#       <td id="T_a32b3_row0_col4" class="data row0 col4" >3320</td>
#     </tr>
#     <tr>
#       <th id="T_a32b3_level0_row1" class="row_heading level0 row1" >Q2_Age</th>
#       <td id="T_a32b3_row1_col0" class="data row1 col0" >1419</td>
#       <td id="T_a32b3_row1_col1" class="data row1 col1" >2156</td>
#       <td id="T_a32b3_row1_col2" class="data row1 col2" >1280</td>
#       <td id="T_a32b3_row1_col3" class="data row1 col3" >3045</td>
#       <td id="T_a32b3_row1_col4" class="data row1 col4" >3176</td>
#     </tr>
#     <tr>
#       <th id="T_a32b3_level0_row2" class="row_heading level0 row2" >Q3_Age</th>
#       <td id="T_a32b3_row2_col0" class="data row2 col0" >1384</td>
#       <td id="T_a32b3_row2_col1" class="data row2 col1" >2438</td>
#       <td id="T_a32b3_row2_col2" class="data row2 col2" >1536</td>
#       <td id="T_a32b3_row2_col3" class="data row2 col3" >3374</td>
#       <td id="T_a32b3_row2_col4" class="data row2 col4" >2934</td>
#     </tr>
#     <tr>
#       <th id="T_a32b3_level0_row3" class="row_heading level0 row3" >Q4_Age</th>
#       <td id="T_a32b3_row3_col0" class="data row3 col0" >1213</td>
#       <td id="T_a32b3_row3_col1" class="data row3 col1" >2395</td>
#       <td id="T_a32b3_row3_col2" class="data row3 col2" >1713</td>
#       <td id="T_a32b3_row3_col3" class="data row3 col3" >3331</td>
#       <td id="T_a32b3_row3_col4" class="data row3 col4" >2469</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e5e98_row0_col0 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_e5e98_row0_col1 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_e5e98_row0_col2 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_e5e98_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e5e98_row0_col4 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_e5e98_row1_col0, #T_e5e98_row2_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e5e98_row1_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_e5e98_row1_col2 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_e5e98_row1_col3 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_e5e98_row1_col4 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_e5e98_row2_col0, #T_e5e98_row3_col1, #T_e5e98_row3_col2, #T_e5e98_row4_col3 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_e5e98_row2_col1, #T_e5e98_row2_col4 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_e5e98_row2_col2 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_e5e98_row3_col0, #T_e5e98_row5_col1, #T_e5e98_row5_col2, #T_e5e98_row5_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e5e98_row3_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_e5e98_row3_col4, #T_e5e98_row4_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_e5e98_row4_col0, #T_e5e98_row5_col0, #T_e5e98_row5_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e5e98_row4_col2 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_e5e98_row4_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# </style>
# <table id="T_e5e98">
#   <caption>Fréquences cumulées par total de campagnes acceptées</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5e98_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_e5e98_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_e5e98_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_e5e98_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_e5e98_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >AcceptedCmp_total</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5e98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5e98_row0_col0" class="data row0 col0" >3855</td>
#       <td id="T_e5e98_row0_col1" class="data row0 col1" >6064</td>
#       <td id="T_e5e98_row0_col2" class="data row0 col2" >3448</td>
#       <td id="T_e5e98_row0_col3" class="data row0 col3" >8940</td>
#       <td id="T_e5e98_row0_col4" class="data row0 col4" >8834</td>
#     </tr>
#     <tr>
#       <th id="T_e5e98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5e98_row1_col0" class="data row1 col0" >909</td>
#       <td id="T_e5e98_row1_col1" class="data row1 col1" >1798</td>
#       <td id="T_e5e98_row1_col2" class="data row1 col2" >1294</td>
#       <td id="T_e5e98_row1_col3" class="data row1 col3" >2344</td>
#       <td id="T_e5e98_row1_col4" class="data row1 col4" >1992</td>
#     </tr>
#     <tr>
#       <th id="T_e5e98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5e98_row2_col0" class="data row2 col0" >318</td>
#       <td id="T_e5e98_row2_col1" class="data row2 col1" >729</td>
#       <td id="T_e5e98_row2_col2" class="data row2 col2" >604</td>
#       <td id="T_e5e98_row2_col3" class="data row2 col3" >913</td>
#       <td id="T_e5e98_row2_col4" class="data row2 col4" >719</td>
#     </tr>
#     <tr>
#       <th id="T_e5e98_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5e98_row3_col0" class="data row3 col0" >78</td>
#       <td id="T_e5e98_row3_col1" class="data row3 col1" >295</td>
#       <td id="T_e5e98_row3_col2" class="data row3 col2" >302</td>
#       <td id="T_e5e98_row3_col3" class="data row3 col3" >396</td>
#       <td id="T_e5e98_row3_col4" class="data row3 col4" >184</td>
#     </tr>
#     <tr>
#       <th id="T_e5e98_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5e98_row4_col0" class="data row4 col0" >38</td>
#       <td id="T_e5e98_row4_col1" class="data row4 col1" >203</td>
#       <td id="T_e5e98_row4_col2" class="data row4 col2" >239</td>
#       <td id="T_e5e98_row4_col3" class="data row4 col3" >289</td>
#       <td id="T_e5e98_row4_col4" class="data row4 col4" >132</td>
#     </tr>
#     <tr>
#       <th id="T_e5e98_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e5e98_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_e5e98_row5_col1" class="data row5 col1" >54</td>
#       <td id="T_e5e98_row5_col2" class="data row5 col2" >69</td>
#       <td id="T_e5e98_row5_col3" class="data row5 col3" >80</td>
#       <td id="T_e5e98_row5_col4" class="data row5 col4" >38</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_deee8_row0_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_deee8_row0_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_deee8_row0_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_deee8_row0_col3 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_deee8_row0_col4 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_deee8_row1_col0 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_deee8_row1_col1 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_deee8_row1_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_deee8_row1_col3 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_deee8_row1_col4 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_deee8_row2_col0 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_deee8_row2_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_deee8_row2_col2 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_deee8_row2_col3 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_deee8_row2_col4 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_deee8_row3_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_deee8_row3_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_deee8_row3_col2 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_deee8_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_deee8_row3_col4 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# </style>
# <table id="T_deee8">
#   <caption>Fréquences cumulées par groupe de revenu</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_deee8_level0_col0" class="col_heading level0 col0" >NumDealsPurchases</th>
#       <th id="T_deee8_level0_col1" class="col_heading level0 col1" >NumWebPurchases</th>
#       <th id="T_deee8_level0_col2" class="col_heading level0 col2" >NumCatalogPurchases</th>
#       <th id="T_deee8_level0_col3" class="col_heading level0 col3" >NumStorePurchases</th>
#       <th id="T_deee8_level0_col4" class="col_heading level0 col4" >NumWebVisitsMonth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Income_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deee8_level0_row0" class="row_heading level0 row0" >Q1_Income</th>
#       <td id="T_deee8_row0_col0" class="data row0 col0" >1155</td>
#       <td id="T_deee8_row0_col1" class="data row0 col1" >1131</td>
#       <td id="T_deee8_row0_col2" class="data row0 col2" >265</td>
#       <td id="T_deee8_row0_col3" class="data row0 col3" >1661</td>
#       <td id="T_deee8_row0_col4" class="data row0 col4" >3920</td>
#     </tr>
#     <tr>
#       <th id="T_deee8_level0_row1" class="row_heading level0 row1" >Q2_Income</th>
#       <td id="T_deee8_row1_col0" class="data row1 col0" >1569</td>
#       <td id="T_deee8_row1_col1" class="data row1 col1" >1961</td>
#       <td id="T_deee8_row1_col2" class="data row1 col2" >689</td>
#       <td id="T_deee8_row1_col3" class="data row1 col3" >2424</td>
#       <td id="T_deee8_row1_col4" class="data row1 col4" >3586</td>
#     </tr>
#     <tr>
#       <th id="T_deee8_level0_row2" class="row_heading level0 row2" >Q3_Income</th>
#       <td id="T_deee8_row2_col0" class="data row2 col0" >1686</td>
#       <td id="T_deee8_row2_col1" class="data row2 col1" >3081</td>
#       <td id="T_deee8_row2_col2" class="data row2 col2" >1813</td>
#       <td id="T_deee8_row2_col3" class="data row2 col3" >4204</td>
#       <td id="T_deee8_row2_col4" class="data row2 col4" >2755</td>
#     </tr>
#     <tr>
#       <th id="T_deee8_level0_row3" class="row_heading level0 row3" >Q4_Income</th>
#       <td id="T_deee8_row3_col0" class="data row3 col0" >795</td>
#       <td id="T_deee8_row3_col1" class="data row3 col1" >2970</td>
#       <td id="T_deee8_row3_col2" class="data row3 col2" >3189</td>
#       <td id="T_deee8_row3_col3" class="data row3 col3" >4673</td>
#       <td id="T_deee8_row3_col4" class="data row3 col4" >1638</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #  Analyse de la Fréquence basée sur les Habitudes de Dépenses

# %%
# Définition des variables quantitatives à agréger (calcul de la somme)
columns_to_analyze = [
    'MntWines', 
    'MntFruits', 
    'MntMeatProducts', 
    'MntFishProducts', 
    'MntSweetProducts', 
    'MntGoldProds'
]

# Définition de la palette de couleurs (séquentielle 'Greens')
# Valeurs basses = vert clair, Valeurs hautes = vert foncé
cmap_colors = 'Greens'

# --- 3. Discrétisation des variables continues (Âge et Revenu) ---
try:
    # Stratégie de discrétisation par quantiles (effectifs égaux)
    df['Age_Group'] = pd.qcut(df['Age'], q=4, labels=['Q1_Age', 'Q2_Age', 'Q3_Age', 'Q4_Age'])
    df['Income_Group'] = pd.qcut(df['Income'], q=4, labels=['Q1_Income', 'Q2_Income', 'Q3_Income', 'Q4_Income'])
except ValueError as e:
    # Fallback : stratégie par intervalles égaux (si qcut échoue, ex: doublons)
    print(f"Erreur de discrétisation (qcut) : {e}. Passage en 'cut'.")
    df['Age_Group'] = pd.cut(df['Age'], bins=4, labels=['Bin1_Age', 'Bin2_Age', 'Bin3_Age', 'Bin4_Age'])
    df['Income_Group'] = pd.cut(df['Income'], bins=4, labels=['Bin1_Income', 'Bin2_Income', 'Bin3_Income', 'Bin4_Income'])



# --- 4. Analyse : Somme des dépenses par Niveau d'études ---
education_analysis = df.groupby('Education')[columns_to_analyze].sum()
display(education_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par niveau d'études"))

# --- 5. Analyse : Somme des dépenses par Statut marital ---
marital_analysis = df.groupby('Marital_Status')[columns_to_analyze].sum()
display(marital_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par statut marital"))

# --- 6. Analyse : Somme des dépenses par Nombre total d'enfants ---
total_kids_analysis = df.groupby('TotalKids')[columns_to_analyze].sum()
display(total_kids_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par nombre total d'enfants"))

# --- 7. Analyse : Somme des dépenses par Enfants (0-12 ans) ---
kidhome_analysis = df.groupby('Kidhome')[columns_to_analyze].sum()
display(kidhome_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par nombre de jeunes enfants"))

# --- 8. Analyse : Somme des dépenses par Adolescents ---
teenhome_analysis = df.groupby('Teenhome')[columns_to_analyze].sum()
display(teenhome_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par nombre d'adolescents"))

# --- 9. Analyse : Somme des dépenses par Groupe d'âge (quartiles) ---
age_group_analysis = df.groupby('Age_Group', observed=True)[columns_to_analyze].sum()
display(age_group_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par groupe d'âge"))

# --- 10. Analyse : Somme des dépenses par Total de campagnes marketing acceptées ---
acceptedcmp_analysis = df.groupby('AcceptedCmp_total')[columns_to_analyze].sum()
display(acceptedcmp_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par total de campagnes acceptées"))

# --- 11. Analyse : Somme des dépenses par Groupe de revenu (quartiles) ---
income_group_analysis = df.groupby('Income_Group', observed=True)[columns_to_analyze].sum()
display(income_group_analysis.style.background_gradient(cmap=cmap_colors, axis=None)
        .set_caption("Dépenses cumulées par groupe de revenu"))
# Out:
# <style type="text/css">
# #T_c48ec_row0_col0 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_c48ec_row0_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_c48ec_row0_col2 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_c48ec_row0_col3, #T_c48ec_row0_col5, #T_c48ec_row4_col1, #T_c48ec_row4_col4 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_c48ec_row0_col4, #T_c48ec_row3_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_c48ec_row1_col0, #T_c48ec_row1_col1, #T_c48ec_row1_col2, #T_c48ec_row1_col3, #T_c48ec_row1_col4, #T_c48ec_row1_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c48ec_row2_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c48ec_row2_col1, #T_c48ec_row2_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_c48ec_row2_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_c48ec_row2_col3 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_c48ec_row2_col5 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_c48ec_row3_col0 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_c48ec_row3_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_c48ec_row3_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_c48ec_row3_col3, #T_c48ec_row4_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_c48ec_row3_col5 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_c48ec_row4_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_c48ec_row4_col2 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c48ec_row4_col5 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# </style>
# <table id="T_c48ec">
#   <caption>Dépenses cumulées par niveau d'études</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c48ec_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_c48ec_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_c48ec_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_c48ec_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_c48ec_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_c48ec_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c48ec_level0_row0" class="row_heading level0 row0" >2n Cycle</th>
#       <td id="T_c48ec_row0_col0" class="data row0 col0" >40208</td>
#       <td id="T_c48ec_row0_col1" class="data row0 col1" >5872</td>
#       <td id="T_c48ec_row0_col2" class="data row0 col2" >28662</td>
#       <td id="T_c48ec_row0_col3" class="data row0 col3" >9625</td>
#       <td id="T_c48ec_row0_col4" class="data row0 col4" >6949</td>
#       <td id="T_c48ec_row0_col5" class="data row0 col5" >9392</td>
#     </tr>
#     <tr>
#       <th id="T_c48ec_level0_row1" class="row_heading level0 row1" >Basic</th>
#       <td id="T_c48ec_row1_col0" class="data row1 col0" >391</td>
#       <td id="T_c48ec_row1_col1" class="data row1 col1" >600</td>
#       <td id="T_c48ec_row1_col2" class="data row1 col2" >618</td>
#       <td id="T_c48ec_row1_col3" class="data row1 col3" >921</td>
#       <td id="T_c48ec_row1_col4" class="data row1 col4" >654</td>
#       <td id="T_c48ec_row1_col5" class="data row1 col5" >1233</td>
#     </tr>
#     <tr>
#       <th id="T_c48ec_level0_row2" class="row_heading level0 row2" >Graduation</th>
#       <td id="T_c48ec_row2_col0" class="data row2 col0" >320371</td>
#       <td id="T_c48ec_row2_col1" class="data row2 col1" >34683</td>
#       <td id="T_c48ec_row2_col2" class="data row2 col2" >202284</td>
#       <td id="T_c48ec_row2_col3" class="data row2 col3" >48630</td>
#       <td id="T_c48ec_row2_col4" class="data row2 col4" >35351</td>
#       <td id="T_c48ec_row2_col5" class="data row2 col5" >57307</td>
#     </tr>
#     <tr>
#       <th id="T_c48ec_level0_row3" class="row_heading level0 row3" >Master</th>
#       <td id="T_c48ec_row3_col0" class="data row3 col0" >123238</td>
#       <td id="T_c48ec_row3_col1" class="data row3 col1" >8012</td>
#       <td id="T_c48ec_row3_col2" class="data row3 col2" >60450</td>
#       <td id="T_c48ec_row3_col3" class="data row3 col3" >11877</td>
#       <td id="T_c48ec_row3_col4" class="data row3 col4" >7835</td>
#       <td id="T_c48ec_row3_col5" class="data row3 col5" >14947</td>
#     </tr>
#     <tr>
#       <th id="T_c48ec_level0_row4" class="row_heading level0 row4" >PhD</th>
#       <td id="T_c48ec_row4_col0" class="data row4 col0" >195830</td>
#       <td id="T_c48ec_row4_col1" class="data row4 col1" >9600</td>
#       <td id="T_c48ec_row4_col2" class="data row4 col2" >81379</td>
#       <td id="T_c48ec_row4_col3" class="data row4 col3" >12886</td>
#       <td id="T_c48ec_row4_col4" class="data row4 col4" >9764</td>
#       <td id="T_c48ec_row4_col5" class="data row4 col5" >15479</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bbd0e_row0_col0, #T_bbd0e_row0_col1, #T_bbd0e_row0_col2, #T_bbd0e_row0_col3, #T_bbd0e_row0_col4, #T_bbd0e_row0_col5, #T_bbd0e_row1_col0, #T_bbd0e_row1_col1, #T_bbd0e_row1_col2, #T_bbd0e_row1_col3, #T_bbd0e_row1_col4, #T_bbd0e_row1_col5, #T_bbd0e_row7_col0, #T_bbd0e_row7_col1, #T_bbd0e_row7_col2, #T_bbd0e_row7_col3, #T_bbd0e_row7_col4, #T_bbd0e_row7_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_bbd0e_row2_col0 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_bbd0e_row2_col1, #T_bbd0e_row2_col4 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_bbd0e_row2_col2 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_bbd0e_row2_col3 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_bbd0e_row2_col5 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_bbd0e_row3_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_bbd0e_row3_col1, #T_bbd0e_row3_col4, #T_bbd0e_row5_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_bbd0e_row3_col2 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_bbd0e_row3_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_bbd0e_row3_col5 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_bbd0e_row4_col0 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_bbd0e_row4_col1, #T_bbd0e_row4_col4 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_bbd0e_row4_col2 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_bbd0e_row4_col3 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_bbd0e_row4_col5 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_bbd0e_row5_col0 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_bbd0e_row5_col1, #T_bbd0e_row5_col4, #T_bbd0e_row6_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_bbd0e_row5_col2 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_bbd0e_row5_col5 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_bbd0e_row6_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_bbd0e_row6_col1, #T_bbd0e_row6_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_bbd0e_row6_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_bbd0e_row6_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# </style>
# <table id="T_bbd0e">
#   <caption>Dépenses cumulées par statut marital</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbd0e_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_bbd0e_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_bbd0e_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_bbd0e_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_bbd0e_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_bbd0e_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Marital_Status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbd0e_level0_row0" class="row_heading level0 row0" >Absurd</th>
#       <td id="T_bbd0e_row0_col0" class="data row0 col0" >711</td>
#       <td id="T_bbd0e_row0_col1" class="data row0 col1" >169</td>
#       <td id="T_bbd0e_row0_col2" class="data row0 col2" >625</td>
#       <td id="T_bbd0e_row0_col3" class="data row0 col3" >411</td>
#       <td id="T_bbd0e_row0_col4" class="data row0 col4" >61</td>
#       <td id="T_bbd0e_row0_col5" class="data row0 col5" >408</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row1" class="row_heading level0 row1" >Alone</th>
#       <td id="T_bbd0e_row1_col0" class="data row1 col0" >554</td>
#       <td id="T_bbd0e_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_bbd0e_row1_col2" class="data row1 col2" >79</td>
#       <td id="T_bbd0e_row1_col3" class="data row1 col3" >23</td>
#       <td id="T_bbd0e_row1_col4" class="data row1 col4" >21</td>
#       <td id="T_bbd0e_row1_col5" class="data row1 col5" >81</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row2" class="row_heading level0 row2" >Divorced</th>
#       <td id="T_bbd0e_row2_col0" class="data row2 col0" >75349</td>
#       <td id="T_bbd0e_row2_col1" class="data row2 col1" >6357</td>
#       <td id="T_bbd0e_row2_col2" class="data row2 col2" >34840</td>
#       <td id="T_bbd0e_row2_col3" class="data row2 col3" >8123</td>
#       <td id="T_bbd0e_row2_col4" class="data row2 col4" >6218</td>
#       <td id="T_bbd0e_row2_col5" class="data row2 col5" >10714</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row3" class="row_heading level0 row3" >Married</th>
#       <td id="T_bbd0e_row3_col0" class="data row3 col0" >258751</td>
#       <td id="T_bbd0e_row3_col1" class="data row3 col1" >22235</td>
#       <td id="T_bbd0e_row3_col2" class="data row3 col2" >138829</td>
#       <td id="T_bbd0e_row3_col3" class="data row3 col3" >30569</td>
#       <td id="T_bbd0e_row3_col4" class="data row3 col4" >23070</td>
#       <td id="T_bbd0e_row3_col5" class="data row3 col5" >36999</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row4" class="row_heading level0 row4" >Single</th>
#       <td id="T_bbd0e_row4_col0" class="data row4 col0" >138391</td>
#       <td id="T_bbd0e_row4_col1" class="data row4 col1" >12881</td>
#       <td id="T_bbd0e_row4_col2" class="data row4 col2" >87407</td>
#       <td id="T_bbd0e_row4_col3" class="data row4 col3" >18337</td>
#       <td id="T_bbd0e_row4_col4" class="data row4 col4" >13086</td>
#       <td id="T_bbd0e_row4_col5" class="data row4 col5" >20988</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row5" class="row_heading level0 row5" >Together</th>
#       <td id="T_bbd0e_row5_col0" class="data row5 col0" >177204</td>
#       <td id="T_bbd0e_row5_col1" class="data row5 col1" >14559</td>
#       <td id="T_bbd0e_row5_col2" class="data row5 col2" >96938</td>
#       <td id="T_bbd0e_row5_col3" class="data row5 col3" >22511</td>
#       <td id="T_bbd0e_row5_col4" class="data row5 col4" >15087</td>
#       <td id="T_bbd0e_row5_col5" class="data row5 col5" >24713</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row6" class="row_heading level0 row6" >Widow</th>
#       <td id="T_bbd0e_row6_col0" class="data row6 col0" >28434</td>
#       <td id="T_bbd0e_row6_col1" class="data row6 col1" >2548</td>
#       <td id="T_bbd0e_row6_col2" class="data row6 col2" >14575</td>
#       <td id="T_bbd0e_row6_col3" class="data row6 col3" >3957</td>
#       <td id="T_bbd0e_row6_col4" class="data row6 col4" >3004</td>
#       <td id="T_bbd0e_row6_col5" class="data row6 col5" >4371</td>
#     </tr>
#     <tr>
#       <th id="T_bbd0e_level0_row7" class="row_heading level0 row7" >YOLO</th>
#       <td id="T_bbd0e_row7_col0" class="data row7 col0" >644</td>
#       <td id="T_bbd0e_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_bbd0e_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_bbd0e_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_bbd0e_row7_col4" class="data row7 col4" >6</td>
#       <td id="T_bbd0e_row7_col5" class="data row7 col5" >84</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e6ab1_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e6ab1_row0_col1, #T_e6ab1_row0_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_e6ab1_row0_col2 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_e6ab1_row0_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_e6ab1_row0_col5 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_e6ab1_row1_col0 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_e6ab1_row1_col1, #T_e6ab1_row2_col2 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_e6ab1_row1_col2 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_e6ab1_row1_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e6ab1_row1_col4 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_e6ab1_row1_col5 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_e6ab1_row2_col0 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_e6ab1_row2_col1, #T_e6ab1_row2_col4, #T_e6ab1_row3_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e6ab1_row2_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_e6ab1_row2_col5 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_e6ab1_row3_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_e6ab1_row3_col1, #T_e6ab1_row3_col3, #T_e6ab1_row3_col4, #T_e6ab1_row3_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e6ab1">
#   <caption>Dépenses cumulées par nombre total d'enfants</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6ab1_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_e6ab1_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_e6ab1_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_e6ab1_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_e6ab1_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_e6ab1_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >TotalKids</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6ab1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6ab1_row0_col0" class="data row0 col0" >310146</td>
#       <td id="T_e6ab1_row0_col1" class="data row0 col1" >33260</td>
#       <td id="T_e6ab1_row0_col2" class="data row0 col2" >237163</td>
#       <td id="T_e6ab1_row0_col3" class="data row0 col3" >48733</td>
#       <td id="T_e6ab1_row0_col4" class="data row0 col4" >33789</td>
#       <td id="T_e6ab1_row0_col5" class="data row0 col5" >40703</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6ab1_row1_col0" class="data row1 col0" >301199</td>
#       <td id="T_e6ab1_row1_col1" class="data row1 col1" >21824</td>
#       <td id="T_e6ab1_row1_col2" class="data row1 col2" >111240</td>
#       <td id="T_e6ab1_row1_col3" class="data row1 col3" >30037</td>
#       <td id="T_e6ab1_row1_col4" class="data row1 col4" >22889</td>
#       <td id="T_e6ab1_row1_col5" class="data row1 col5" >45967</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6ab1_row2_col0" class="data row2 col0" >59610</td>
#       <td id="T_e6ab1_row2_col1" class="data row2 col1" >3317</td>
#       <td id="T_e6ab1_row2_col2" class="data row2 col2" >21597</td>
#       <td id="T_e6ab1_row2_col3" class="data row2 col3" >4794</td>
#       <td id="T_e6ab1_row2_col4" class="data row2 col4" >3524</td>
#       <td id="T_e6ab1_row2_col5" class="data row2 col5" >10702</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6ab1_row3_col0" class="data row3 col0" >9083</td>
#       <td id="T_e6ab1_row3_col1" class="data row3 col1" >366</td>
#       <td id="T_e6ab1_row3_col2" class="data row3 col2" >3393</td>
#       <td id="T_e6ab1_row3_col3" class="data row3 col3" >375</td>
#       <td id="T_e6ab1_row3_col4" class="data row3 col4" >351</td>
#       <td id="T_e6ab1_row3_col5" class="data row3 col5" >986</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e987e_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e987e_row0_col1, #T_e987e_row0_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_e987e_row0_col2 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_e987e_row0_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_e987e_row0_col5 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_e987e_row1_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_e987e_row1_col1, #T_e987e_row1_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_e987e_row1_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_e987e_row1_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_e987e_row1_col5 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_e987e_row2_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e987e_row2_col1, #T_e987e_row2_col2, #T_e987e_row2_col3, #T_e987e_row2_col4, #T_e987e_row2_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e987e">
#   <caption>Dépenses cumulées par nombre de jeunes enfants</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e987e_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_e987e_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_e987e_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_e987e_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_e987e_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_e987e_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Kidhome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e987e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e987e_row0_col0" class="data row0 col0" >582604</td>
#       <td id="T_e987e_row0_col1" class="data row0 col1" >50791</td>
#       <td id="T_e987e_row0_col2" class="data row0 col2" >327850</td>
#       <td id="T_e987e_row0_col3" class="data row0 col3" >72507</td>
#       <td id="T_e987e_row0_col4" class="data row0 col4" >52301</td>
#       <td id="T_e987e_row0_col5" class="data row0 col5" >77402</td>
#     </tr>
#     <tr>
#       <th id="T_e987e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e987e_row1_col0" class="data row1 col0" >93844</td>
#       <td id="T_e987e_row1_col1" class="data row1 col1" >7651</td>
#       <td id="T_e987e_row1_col2" class="data row1 col2" >43919</td>
#       <td id="T_e987e_row1_col3" class="data row1 col3" >11061</td>
#       <td id="T_e987e_row1_col4" class="data row1 col4" >8026</td>
#       <td id="T_e987e_row1_col5" class="data row1 col5" >20120</td>
#     </tr>
#     <tr>
#       <th id="T_e987e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e987e_row2_col0" class="data row2 col0" >3590</td>
#       <td id="T_e987e_row2_col1" class="data row2 col1" >325</td>
#       <td id="T_e987e_row2_col2" class="data row2 col2" >1624</td>
#       <td id="T_e987e_row2_col3" class="data row2 col3" >371</td>
#       <td id="T_e987e_row2_col4" class="data row2 col4" >226</td>
#       <td id="T_e987e_row2_col5" class="data row2 col5" >836</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3af9b_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3af9b_row0_col1, #T_3af9b_row0_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_3af9b_row0_col2 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_3af9b_row0_col3 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_3af9b_row0_col5 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_3af9b_row1_col0 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_3af9b_row1_col1, #T_3af9b_row2_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_3af9b_row1_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_3af9b_row1_col3 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_3af9b_row1_col4 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_3af9b_row1_col5 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_3af9b_row2_col1, #T_3af9b_row2_col3, #T_3af9b_row2_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3af9b_row2_col2 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_3af9b_row2_col5 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# </style>
# <table id="T_3af9b">
#   <caption>Dépenses cumulées par nombre d'adolescents</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3af9b_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_3af9b_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_3af9b_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_3af9b_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_3af9b_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_3af9b_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Teenhome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3af9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3af9b_row0_col0" class="data row0 col0" >352215</td>
#       <td id="T_3af9b_row0_col1" class="data row0 col1" >38423</td>
#       <td id="T_3af9b_row0_col2" class="data row0 col2" >262435</td>
#       <td id="T_3af9b_row0_col3" class="data row0 col3" >56235</td>
#       <td id="T_3af9b_row0_col4" class="data row0 col4" >38877</td>
#       <td id="T_3af9b_row0_col5" class="data row0 col5" >52158</td>
#     </tr>
#     <tr>
#       <th id="T_3af9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3af9b_row1_col0" class="data row1 col0" >309002</td>
#       <td id="T_3af9b_row1_col1" class="data row1 col1" >19433</td>
#       <td id="T_3af9b_row1_col2" class="data row1 col2" >104470</td>
#       <td id="T_3af9b_row1_col3" class="data row1 col3" >26461</td>
#       <td id="T_3af9b_row1_col4" class="data row1 col4" >20840</td>
#       <td id="T_3af9b_row1_col5" class="data row1 col5" >43863</td>
#     </tr>
#     <tr>
#       <th id="T_3af9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3af9b_row2_col0" class="data row2 col0" >18821</td>
#       <td id="T_3af9b_row2_col1" class="data row2 col1" >911</td>
#       <td id="T_3af9b_row2_col2" class="data row2 col2" >6488</td>
#       <td id="T_3af9b_row2_col3" class="data row2 col3" >1243</td>
#       <td id="T_3af9b_row2_col4" class="data row2 col4" >836</td>
#       <td id="T_3af9b_row2_col5" class="data row2 col5" >2337</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d1ba5_row0_col0 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_d1ba5_row0_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_d1ba5_row0_col2 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_d1ba5_row0_col3, #T_d1ba5_row3_col3 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_d1ba5_row0_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_d1ba5_row0_col5, #T_d1ba5_row2_col5 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_d1ba5_row1_col0 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_d1ba5_row1_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_d1ba5_row1_col2 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_d1ba5_row1_col3 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_d1ba5_row1_col4, #T_d1ba5_row2_col4, #T_d1ba5_row3_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_d1ba5_row1_col5 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_d1ba5_row2_col0 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_d1ba5_row2_col1, #T_d1ba5_row3_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_d1ba5_row2_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_d1ba5_row2_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_d1ba5_row3_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d1ba5_row3_col2 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_d1ba5_row3_col5 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# </style>
# <table id="T_d1ba5">
#   <caption>Dépenses cumulées par groupe d'âge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1ba5_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_d1ba5_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_d1ba5_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_d1ba5_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_d1ba5_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_d1ba5_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1ba5_level0_row0" class="row_heading level0 row0" >Q1_Age</th>
#       <td id="T_d1ba5_row0_col0" class="data row0 col0" >143847</td>
#       <td id="T_d1ba5_row0_col1" class="data row0 col1" >16356</td>
#       <td id="T_d1ba5_row0_col2" class="data row0 col2" >105310</td>
#       <td id="T_d1ba5_row0_col3" class="data row0 col3" >22783</td>
#       <td id="T_d1ba5_row0_col4" class="data row0 col4" >16731</td>
#       <td id="T_d1ba5_row0_col5" class="data row0 col5" >25810</td>
#     </tr>
#     <tr>
#       <th id="T_d1ba5_level0_row1" class="row_heading level0 row1" >Q2_Age</th>
#       <td id="T_d1ba5_row1_col0" class="data row1 col0" >152155</td>
#       <td id="T_d1ba5_row1_col1" class="data row1 col1" >13069</td>
#       <td id="T_d1ba5_row1_col2" class="data row1 col2" >80060</td>
#       <td id="T_d1ba5_row1_col3" class="data row1 col3" >18599</td>
#       <td id="T_d1ba5_row1_col4" class="data row1 col4" >14054</td>
#       <td id="T_d1ba5_row1_col5" class="data row1 col5" >21063</td>
#     </tr>
#     <tr>
#       <th id="T_d1ba5_level0_row2" class="row_heading level0 row2" >Q3_Age</th>
#       <td id="T_d1ba5_row2_col0" class="data row2 col0" >187726</td>
#       <td id="T_d1ba5_row2_col1" class="data row2 col1" >15303</td>
#       <td id="T_d1ba5_row2_col2" class="data row2 col2" >87795</td>
#       <td id="T_d1ba5_row2_col3" class="data row2 col3" >19963</td>
#       <td id="T_d1ba5_row2_col4" class="data row2 col4" >14336</td>
#       <td id="T_d1ba5_row2_col5" class="data row2 col5" >25338</td>
#     </tr>
#     <tr>
#       <th id="T_d1ba5_level0_row3" class="row_heading level0 row3" >Q4_Age</th>
#       <td id="T_d1ba5_row3_col0" class="data row3 col0" >196310</td>
#       <td id="T_d1ba5_row3_col1" class="data row3 col1" >14039</td>
#       <td id="T_d1ba5_row3_col2" class="data row3 col2" >100228</td>
#       <td id="T_d1ba5_row3_col3" class="data row3 col3" >22594</td>
#       <td id="T_d1ba5_row3_col4" class="data row3 col4" >15432</td>
#       <td id="T_d1ba5_row3_col5" class="data row3 col5" >26147</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_365ba_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_365ba_row0_col1, #T_365ba_row0_col4 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_365ba_row0_col2 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_365ba_row0_col3 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_365ba_row0_col5 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_365ba_row1_col0 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_365ba_row1_col1, #T_365ba_row1_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_365ba_row1_col2 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_365ba_row1_col3, #T_365ba_row4_col2 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_365ba_row1_col5 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_365ba_row2_col0 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_365ba_row2_col1, #T_365ba_row2_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_365ba_row2_col2, #T_365ba_row3_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_365ba_row2_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_365ba_row2_col5 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_365ba_row3_col1, #T_365ba_row3_col3, #T_365ba_row3_col4, #T_365ba_row3_col5, #T_365ba_row4_col1, #T_365ba_row4_col3, #T_365ba_row4_col4, #T_365ba_row4_col5, #T_365ba_row5_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_365ba_row3_col2 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_365ba_row4_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_365ba_row5_col0 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_365ba_row5_col1, #T_365ba_row5_col3, #T_365ba_row5_col4, #T_365ba_row5_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_365ba">
#   <caption>Dépenses cumulées par total de campagnes acceptées</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_365ba_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_365ba_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_365ba_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_365ba_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_365ba_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_365ba_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >AcceptedCmp_total</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_365ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_365ba_row0_col0" class="data row0 col0" >353420</td>
#       <td id="T_365ba_row0_col1" class="data row0 col1" >37081</td>
#       <td id="T_365ba_row0_col2" class="data row0 col2" >205094</td>
#       <td id="T_365ba_row0_col3" class="data row0 col3" >52295</td>
#       <td id="T_365ba_row0_col4" class="data row0 col4" >37369</td>
#       <td id="T_365ba_row0_col5" class="data row0 col5" >61830</td>
#     </tr>
#     <tr>
#       <th id="T_365ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_365ba_row1_col0" class="data row1 col0" >157468</td>
#       <td id="T_365ba_row1_col1" class="data row1 col1" >11524</td>
#       <td id="T_365ba_row1_col2" class="data row1 col2" >86686</td>
#       <td id="T_365ba_row1_col3" class="data row1 col3" >17059</td>
#       <td id="T_365ba_row1_col4" class="data row1 col4" >12071</td>
#       <td id="T_365ba_row1_col5" class="data row1 col5" >20475</td>
#     </tr>
#     <tr>
#       <th id="T_365ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_365ba_row2_col0" class="data row2 col0" >85026</td>
#       <td id="T_365ba_row2_col1" class="data row2 col1" >5023</td>
#       <td id="T_365ba_row2_col2" class="data row2 col2" >40966</td>
#       <td id="T_365ba_row2_col3" class="data row2 col3" >7151</td>
#       <td id="T_365ba_row2_col4" class="data row2 col4" >5363</td>
#       <td id="T_365ba_row2_col5" class="data row2 col5" >7927</td>
#     </tr>
#     <tr>
#       <th id="T_365ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_365ba_row3_col0" class="data row3 col0" >41665</td>
#       <td id="T_365ba_row3_col1" class="data row3 col1" >2640</td>
#       <td id="T_365ba_row3_col2" class="data row3 col2" >19676</td>
#       <td id="T_365ba_row3_col3" class="data row3 col3" >4508</td>
#       <td id="T_365ba_row3_col4" class="data row3 col4" >2932</td>
#       <td id="T_365ba_row3_col5" class="data row3 col5" >4412</td>
#     </tr>
#     <tr>
#       <th id="T_365ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_365ba_row4_col0" class="data row4 col0" >32991</td>
#       <td id="T_365ba_row4_col1" class="data row4 col1" >2099</td>
#       <td id="T_365ba_row4_col2" class="data row4 col2" >17349</td>
#       <td id="T_365ba_row4_col3" class="data row4 col3" >2449</td>
#       <td id="T_365ba_row4_col4" class="data row4 col4" >2237</td>
#       <td id="T_365ba_row4_col5" class="data row4 col5" >3122</td>
#     </tr>
#     <tr>
#       <th id="T_365ba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_365ba_row5_col0" class="data row5 col0" >9468</td>
#       <td id="T_365ba_row5_col1" class="data row5 col1" >400</td>
#       <td id="T_365ba_row5_col2" class="data row5 col2" >3622</td>
#       <td id="T_365ba_row5_col3" class="data row5 col3" >477</td>
#       <td id="T_365ba_row5_col4" class="data row5 col4" >581</td>
#       <td id="T_365ba_row5_col5" class="data row5 col5" >592</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e186c_row0_col0, #T_e186c_row0_col2 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_e186c_row0_col1, #T_e186c_row0_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e186c_row0_col3, #T_e186c_row1_col1, #T_e186c_row1_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e186c_row0_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_e186c_row1_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_e186c_row1_col2, #T_e186c_row2_col5 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_e186c_row1_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_e186c_row1_col5, #T_e186c_row2_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_e186c_row2_col0 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_e186c_row2_col2 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_e186c_row2_col3 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_e186c_row2_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_e186c_row3_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e186c_row3_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_e186c_row3_col2 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_e186c_row3_col3 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_e186c_row3_col4 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e186c_row3_col5 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# </style>
# <table id="T_e186c">
#   <caption>Dépenses cumulées par groupe de revenu</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e186c_level0_col0" class="col_heading level0 col0" >MntWines</th>
#       <th id="T_e186c_level0_col1" class="col_heading level0 col1" >MntFruits</th>
#       <th id="T_e186c_level0_col2" class="col_heading level0 col2" >MntMeatProducts</th>
#       <th id="T_e186c_level0_col3" class="col_heading level0 col3" >MntFishProducts</th>
#       <th id="T_e186c_level0_col4" class="col_heading level0 col4" >MntSweetProducts</th>
#       <th id="T_e186c_level0_col5" class="col_heading level0 col5" >MntGoldProds</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Income_Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e186c_level0_row0" class="row_heading level0 row0" >Q1_Income</th>
#       <td id="T_e186c_row0_col0" class="data row0 col0" >12284</td>
#       <td id="T_e186c_row0_col1" class="data row0 col1" >3310</td>
#       <td id="T_e186c_row0_col2" class="data row0 col2" >12725</td>
#       <td id="T_e186c_row0_col3" class="data row0 col3" >4835</td>
#       <td id="T_e186c_row0_col4" class="data row0 col4" >3302</td>
#       <td id="T_e186c_row0_col5" class="data row0 col5" >9424</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row1" class="row_heading level0 row1" >Q2_Income</th>
#       <td id="T_e186c_row1_col0" class="data row1 col0" >73525</td>
#       <td id="T_e186c_row1_col1" class="data row1 col1" >4932</td>
#       <td id="T_e186c_row1_col2" class="data row1 col2" >30453</td>
#       <td id="T_e186c_row1_col3" class="data row1 col3" >8138</td>
#       <td id="T_e186c_row1_col4" class="data row1 col4" >5437</td>
#       <td id="T_e186c_row1_col5" class="data row1 col5" >16630</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row2" class="row_heading level0 row2" >Q3_Income</th>
#       <td id="T_e186c_row2_col0" class="data row2 col0" >239071</td>
#       <td id="T_e186c_row2_col1" class="data row2 col1" >16725</td>
#       <td id="T_e186c_row2_col2" class="data row2 col2" >86925</td>
#       <td id="T_e186c_row2_col3" class="data row2 col3" >21581</td>
#       <td id="T_e186c_row2_col4" class="data row2 col4" >15463</td>
#       <td id="T_e186c_row2_col5" class="data row2 col5" >32102</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row3" class="row_heading level0 row3" >Q4_Income</th>
#       <td id="T_e186c_row3_col0" class="data row3 col0" >355158</td>
#       <td id="T_e186c_row3_col1" class="data row3 col1" >33800</td>
#       <td id="T_e186c_row3_col2" class="data row3 col2" >243290</td>
#       <td id="T_e186c_row3_col3" class="data row3 col3" >49385</td>
#       <td id="T_e186c_row3_col4" class="data row3 col4" >36351</td>
#       <td id="T_e186c_row3_col5" class="data row3 col5" >40202</td>
#     </tr>
#   </tbody>
# </table>
